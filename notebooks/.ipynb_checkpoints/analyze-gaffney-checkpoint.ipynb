# %%
# import pandas
import pandas as pd

# %%
# read the csv in
df = pd.read_csv('../data/warn-gaffney.csv')

# %%
# print df
df
# Out:
#      notice_date                   reason  \
# 0      4/21/2020             Plant Layoff
# 1      4/27/2020   Temporary Plant Layoff
# 2      4/27/2020  Temporary Plant Closing
# 3      4/27/2020  Temporary Plant Closing
# 4      4/27/2020  Temporary Plant Closing
# ...          ...                      ...
# 1280    1/6/2020            Plant Closing
# 1281  12/27/2019  Temporary Plant Closing
# 1282  12/30/2019            Plant Closing
# 1283  12/30/2019            Plant Closing
# 1284  12/23/2019            Plant Closing
#
#                                                 company  \
# 0      GCT New York LP (Global Container Terminals USA)
# 1     OS Restaurant Services, LLC (Bloomin Brands- O...
# 2     OS Restaurant Services, LLC (Bloomin Brands - ...
# 3     OS Restaurant Services, LLC (Bloomin Brands - ...
# 4     OS Restaurant Services, LLC (Bloomin Brands - ...
# ...                                                 ...
# 1280  Macy's Broadway Mall Store (Macy's Retail Hold...
# ...

# %%
# create a variable
warn = pd.read_csv('../data/warn-gaffney.csv')

# %%
# see what we're working with in this data
warn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1285 entries, 0 to 1284
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   notice_date      1285 non-null   object
#  1   reason           1285 non-null   object
#  2   company          1285 non-null   object
#  3   address          1284 non-null   object
#  4   county           1285 non-null   object
#  5   phone            1285 non-null   object
#  6   business_type    1285 non-null   object
#  7   affected         1205 non-null   object
#  8   total_employees  516 non-null    object
#  9   layoff_date      1282 non-null   object
#  10  dislocation      1285 non-null   object
#  11  union            1285 non-null   object
#  12  classification   1285 non-null   object
# dtypes: object(13)
# memory usage: 130.6+ KB

# %%
# see all the different reasons the businesses closed
warn.reason
# Out:
# 0                  Plant Layoff
# 1        Temporary Plant Layoff
# 2       Temporary Plant Closing
# 3       Temporary Plant Closing
# 4       Temporary Plant Closing
#                  ...
# 1280              Plant Closing
# 1281    Temporary Plant Closing
# 1282              Plant Closing
# 1283              Plant Closing
# 1284              Plant Closing
# Name: reason, Length: 1285, dtype: object

# %%
# sum of reasons the businesses closed 
warn.reason.value_counts()
# Out:
# Temporary Plant Layoff                       609
# Temporary Plant Closing                      444
# Plant Closing                                 88
# Plant Layoff                                  74
# Temporary Layoff                              12
# Temporary Closing                              7
# Temporary Plant  Layoff                        5
# Temporary  Plant Closing                       3
# Plant Unit Closing                             3
# Possible Plant Layoff                          3
# Temporary Plant  Closing                       3
# Temporary Plant Layoff (Furlough)              3
# Plant Layoff (Conditional)                     2
# Possible Plant Layoff/Closing                  2
# Temporary Plant Layoff/Plant Layoff            1
# Temporary Plant \nClosing                      1
# Temporary Unit Closing                         1
# Temporary  Plant Closing                       1
# Plant Demolition                               1
# ...

# %%
# see types of businesses that have closed
warn.business_type
# Out:
# 0                                   Marine Cargo Handling
# 1                                              Restaurant
# 2                                              Restaurant
# 3                                              Restaurant
# 4                                              Restaurant
#                               ...
# 1280                                         Retail Store
# 1281                                         Nursing Home
# 1282                                           Restaurant
# 1283    Trucking company providing freight transportat...
# 1284                                         Resort Hotel
# Name: business_type, Length: 1285, dtype: object

# %%
# sum of types of closed businesses
warn.business_type.value_counts()[:20]
# Out:
# Restaurant                            493
# Hotel                                 145
# Retail                                 43
# Auto Dealership                        24
# Catering                               16
# Building Services                      10
# Retail clothing store                  10
# Eye Care                               10
# School                                  8
# Gym                                     8
# Auto Sales                              7
# Realty                                  7
# Transportation                          7
# Airline Services                        6
# Home Health Care                        6
# Car Rental                              6
# Shoe Store                              6
# Family planning services                6
# Leading global IT services company      6
# Clothing Retail                         5
# Name: business_type, dtype: int64

# %%
# sum of dates businesses closed on
warn.layoff_date.value_counts()
# Out:
# 3/16/2020     185
# 3/17/2020     112
# 3/20/2020      89
# 3/23/2020      79
# 3/18/2020      77
#              ...
# 18              1
# 87              1
# 72              1
# 3/19/2020,      1
# 81              1
# Name: layoff_date, Length: 121, dtype: int64

# %%
# new df of the dates businesses laid off the most
warndays = warn.layoff_date.value_counts()
warndays
# Out:
# 3/16/2020     185
# 3/17/2020     112
# 3/20/2020      89
# 3/23/2020      79
# 3/18/2020      77
#              ...
# 18              1
# 87              1
# 72              1
# 3/19/2020,      1
# 81              1
# Name: layoff_date, Length: 121, dtype: int64

# %%
# checking dtype of the total_employees column
type(warn['total_employees'][0])
# Out:
# numpy.float64

# %%
# weirdly I did this the first time and needed to convert the dtype but then I went back and changed something completely unrelated and when re-playing all the lines, the conversion didn't work and it turns out I didn't need to convert the dtype anymore.  So, anyway, now I can go straight into finding the sum of all the affected employees!
warn.total_employees.sum()
# Out:
# 72878.0

# %%
# defining the category Restaurant within business types so that I can sort out the other types
restaurants = 'Restaurant'

# %%
# looking only at the closed restaurants
warn[warn.business_type == restaurants]
# Out:
#      notice_date                   reason  \
# 1      4/27/2020   Temporary Plant Layoff
# 2      4/27/2020  Temporary Plant Closing
# 3      4/27/2020  Temporary Plant Closing
# 4      4/27/2020  Temporary Plant Closing
# 5      4/27/2020  Temporary Plant Closing
# ...          ...                      ...
# 1205   3/17/2020  Temporary Plant Closing
# 1208   3/17/2020   Temporary Plant Layoff
# 1209    3/5/2020            Plant Closing
# 1216   7/13/2018            Plant Closing
# 1282  12/30/2019            Plant Closing
#
#                                                 company  \
# 1     OS Restaurant Services, LLC (Bloomin Brands- O...
# 2     OS Restaurant Services, LLC (Bloomin Brands - ...
# 3     OS Restaurant Services, LLC (Bloomin Brands - ...
# 4     OS Restaurant Services, LLC (Bloomin Brands - ...
# 5     OS Restaurant Services, LLC (Bloomin Brands - ...
# ...                                                 ...
# 1205                                100 Hospitality LLC
# ...

# %%
# making a new df out of the Restaurants Only table
warnfood = warn[warn.business_type == restaurants]

# %%
warnfood
# Out:
#      notice_date                   reason  \
# 1      4/27/2020   Temporary Plant Layoff
# 2      4/27/2020  Temporary Plant Closing
# 3      4/27/2020  Temporary Plant Closing
# 4      4/27/2020  Temporary Plant Closing
# 5      4/27/2020  Temporary Plant Closing
# ...          ...                      ...
# 1205   3/17/2020  Temporary Plant Closing
# 1208   3/17/2020   Temporary Plant Layoff
# 1209    3/5/2020            Plant Closing
# 1216   7/13/2018            Plant Closing
# 1282  12/30/2019            Plant Closing
#
#                                                 company  \
# 1     OS Restaurant Services, LLC (Bloomin Brands- O...
# 2     OS Restaurant Services, LLC (Bloomin Brands - ...
# 3     OS Restaurant Services, LLC (Bloomin Brands - ...
# 4     OS Restaurant Services, LLC (Bloomin Brands - ...
# 5     OS Restaurant Services, LLC (Bloomin Brands - ...
# ...                                                 ...
# 1205                                100 Hospitality LLC
# ...

# %%
# print warnfood
warnfood
# Out:
#      notice_date                   reason  \
# 1      4/27/2020   Temporary Plant Layoff
# 2      4/27/2020  Temporary Plant Closing
# 3      4/27/2020  Temporary Plant Closing
# 4      4/27/2020  Temporary Plant Closing
# 5      4/27/2020  Temporary Plant Closing
# ...          ...                      ...
# 1205   3/17/2020  Temporary Plant Closing
# 1208   3/17/2020   Temporary Plant Layoff
# 1209    3/5/2020            Plant Closing
# 1216   7/13/2018            Plant Closing
# 1282  12/30/2019            Plant Closing
#
#                                                 company  \
# 1     OS Restaurant Services, LLC (Bloomin Brands- O...
# 2     OS Restaurant Services, LLC (Bloomin Brands - ...
# 3     OS Restaurant Services, LLC (Bloomin Brands - ...
# 4     OS Restaurant Services, LLC (Bloomin Brands - ...
# 5     OS Restaurant Services, LLC (Bloomin Brands - ...
# ...                                                 ...
# 1205                                100 Hospitality LLC
# ...

# %%
# sum of total restaurant employees affected
warnfood.total_employees.sum()
# Out:
# 21957.0

# %%
# how many restaurants are unionized
warnfood.union.value_counts()
# Out:
# The employees are not represented by a union                 455
# The employees are not represented by a union.                 25
# The employees are not represented by a union. Non Union        6
# UniteHere Local 100                                            1
# UNITE HERE Local 100                                           1
# Laundry, Distribution and Food Services Joint Board            1
# UNITE HERE, Local 100                                          1
# Unite Here Local 100                                           1
# Local 100                                                      1
# Local  1102 Retail, Wholesale and Department  Store Union      1
# Name: union, dtype: int64

# %%
# sum of dates restaurants closed on
warnfood.layoff_date.value_counts()
# Out:
# 3/16/2020     155
# 3/17/2020      71
# 3/15/2020      53
# 3/18/2020      39
# 3/20/2020      27
# 3/23/2020      27
# 3/31/2020      16
# 4/8/2020       13
# 3/26/2020      10
# 3/19/2020       9
# 3/21/2020       8
# 4/13/2020       8
# 3/14/2020       5
# 3/29/2020       5
# 3/22/2020       4
# 3/30/2020       4
# 3/13/2020       3
# Separation      3
# 3/25/2020       3
# 3/12/2020       2
# The             2
# 3/27/2020       2
# A               2
# 3/11/2020       2
# Close           2
# 4/12/2020       2
# -----           2
# 88              1
# 330             1
# 7/31/2020       1
# 81              1
# 356             1
# 2/23/2020       1
# 3/24/2020       1
# 5/1/2020        1
# 3/6/2020        1
# 86              1
# March           1
# 51              1
# 362             1
# 3/10/2020       1
# Name: layoff_date, dtype: int64

# %%
# new df of the dates restaurants laid off the most
warnfooddays = warnfood.layoff_date.value_counts()
warnfooddays
# Out:
# 3/16/2020     155
# 3/17/2020      71
# 3/15/2020      53
# 3/18/2020      39
# 3/20/2020      27
# 3/23/2020      27
# 3/31/2020      16
# 4/8/2020       13
# 3/26/2020      10
# 3/19/2020       9
# 3/21/2020       8
# 4/13/2020       8
# 3/14/2020       5
# 3/29/2020       5
# 3/22/2020       4
# 3/30/2020       4
# 3/13/2020       3
# Separation      3
# 3/25/2020       3
# 3/12/2020       2
# The             2
# 3/27/2020       2
# A               2
# 3/11/2020       2
# Close           2
# 4/12/2020       2
# -----           2
# 88              1
# 330             1
# 7/31/2020       1
# 81              1
# 356             1
# 2/23/2020       1
# 3/24/2020       1
# 5/1/2020        1
# 3/6/2020        1
# 86              1
# March           1
# 51              1
# 362             1
# 3/10/2020       1
# Name: layoff_date, dtype: int64

# %%
warndays.to_csv('..data.warndays.csv')

# %%
warnfooddays.to_csv('..data.warnfooddays.csv')
